# %%
import pandas as pd
data = {
    'Name': ['Arun', 'Priya', 'Rahul', 'Sneha', 'Kiran'],
    'Age': [22, 25, None, 24, 23],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [30000, 35000, 32000, None, 34000]
}
df = pd.DataFrame(data)
print("Original Dataset:")
print(df)
print("\nMissing Values:")
print(df.isnull().sum())
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
print("\nCleaned Dataset:")
print(df)
# Out:
# Original Dataset:
#     Name   Age Department   Salary
# 0   Arun  22.0         IT  30000.0
# 1  Priya  25.0         HR  35000.0
# 2  Rahul   NaN         IT  32000.0
# 3  Sneha  24.0    Finance      NaN
# 4  Kiran  23.0         HR  34000.0
#
# Missing Values:
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64
#
# Cleaned Dataset:
#     Name   Age Department   Salary
# 0   Arun  22.0         IT  30000.0
# 1  Priya  25.0         HR  35000.0
# 2  Rahul  23.5         IT  32000.0
# 3  Sneha  24.0    Finance  32750.0
# 4  Kiran  23.0         HR  34000.0
